# %%
# Purpose: to check if the lab is ready

import numpy as np
import pandas as pd
print("Lab ready:", np.__version__, pd.__version__)
# Out:
# Lab ready: 2.5.2 3.0.5

# %% [markdown]
# # Week 01: Python Basics
#
# **Course:** MATH7810 Python for Data Science (AY2026/27)
#
# ## Before you start
# Complete **AccountSetUp**, then in class follow the repo **README** to fork, open a Codespace, and run the green-light check.
#
# ## This notebook
# Work through in order: **values & types → variables → operators → strings → input → booleans → conditionals → exercise**.
#
# ---

# %% [markdown]
# # Values and Types
# A value is one of the basic things a program works with, like a letter
# or a number.

# %%
print(4)
# Out:
# 4

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print(3.2)
# Out:
# 3.2

# %%
print(True)
# Out:
# True

# %%
type(4)
# Out:
# int

# %%
type(3.2)
# Out:
# float

# %%
type("Hello World")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # Variables
# A variable is a specific, **case-sensitive** name that refers to a value.
#
# One of the most powerful features of a programming language is the ability to **manipulate** variables.
#
# An **assignment statement** creates new variables and gives them values.

# %%
message = 'And now for something completely different'
n = 17
N = 18
pi = 3.14
print(message)
print(n)
print(N)
print(pi)
# Out:
# And now for something completely different
# 17
# 18
# 3.14

# %% [markdown]
# # Variable names
#
# - Variable names contain both letters and numbers, but they CANNOT start with a number.
#
# - The underscore character ( _ ) can appear in a name. It is often used in names with multiple words, such as my_name or airspeed_of_unladen_swallow.
#
# - If you give a variable an illegal name, you get a syntax error:

# %%
76abc = 'a'
# Out:
#   Cell In[11], line 1
#     76abc = 'a'
#      ^
# SyntaxError: invalid decimal literal

# %%
more@ = 1000

# %% [markdown]
# Python reserves 35 keywords:
# and del from None True as elif global nonlocal try assert else if not while break except import or with class False in pass yield continue finally is raise async def for lambda return await
#
# Keywords **can not** be used as variable names.

# %%
class = 'abc'

# %% [markdown]
# # Operators and operands
# Operators are special symbols that represent computations like addition and multiplication. The values the operator is applied to are called operands.

# %%
# Basic operations
print(1 + 2)
print(1 - 2)
print(1 * 2)
print(1 / 2)

# %%
# exponentiation
7**2

# %%
# The bitwise XOR operator, not the exponentiation as used in Excel or R
7^2

# %%
# The modulo operator / remainder
7%2

# %%
7.5%2

# %%
# The floor division operator which returns the largest integer that is less than or equal to the division result.
7//2

# %%
-7//2

# %% [markdown]
# Order of operations
# - When more than one operator appears in an expression, the order of evaluation depends on the rules of precedence. For mathematical operators, Python follows mathematical convention.
#
# - Parentheses have the highest precedence and can be used to force an
# expression to evaluate in the order you want.
#
# - Exponentiation has the next highest precedence.
#
# - Multiplication and Division have the same precedence, which is higher
# than Addition and Subtraction, which also have the same precedence.
#
# - Operators with the same precedence are evaluated from left to right.

# %% [markdown]
# # String operations
#
# When the + operator is used with strings, it concatenates them.

# %%
first = 10
second = 15
# Find the sum of first and second
print(first + second)
# Out:
# 25

# %%
first = "10"
second = "15"
# Paste the two variables together
print(first + second)
# Out:
# 1015

# %%
first = "10"
second = 5
print(first * second)

# %% [markdown]
# For different type of data, the operator works differently.

# %% [markdown]
# # Asking for input

# %%
inp = input()
print(inp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 inp = input()
#       2 print(inp)
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# ...

# %%
name = input('What is your name?\n') # The '\n' means 'newline'
print(name)

# %%
type(name)

# %% [markdown]
# # Exercise

# %%
#1
name = input('Enter your name:\n')
print('Hello ' + name)

# %% [markdown]
# # Boolean expressions
# A Boolean expression is an expression that is either true or false.

# %%
5 == 6
# Out:
# False

# %%
type(TRUE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 type(TRUE)
#
# NameError: name 'TRUE' is not defined

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # Logical operators
#
# There are three logical operators:
# - and
# - or
# - not

# %%
x = 3
print(x > 0  and x < 10)
# Out:
# True

# %%
n = 3
print(n%2 == 0 or n%3 == 0)
# Out:
# True

# %% [markdown]
# Any non-zero number is interpreted as “True”.

# %%
print(17 and True)
# Out:
# True

# %% [markdown]
# # Conditional execution
#
# In order to write useful programs, we almost always need to check conditions and change the behavior of the program accordingly.
# The simplest form of conditional statement is the 'if' statement.

# %%
x = 10
if x > 0:
    print('x is positive')

# %% [markdown]
# A second form of the if statement is alternative execution, in which there are two possibilities and the condition determines which one gets executed.

# %%
def pos(x):
    if x > 0:
        return 'x is positive'
    else:
        return 'x is non-positive'
pos(-1)

# %% [markdown]
# In Python, indentation is crucial for determining the structure and scope of the code.

# %%
#for integer input x
def evenodd(x):
    if x % 2 == 0:
        return 'x is even'
    else:
        return 'x is odd'
evenodd(4)

# %% [markdown]
# Sometimes there are more than two possible outcomes, so we need more than two branches in our code. One way to handle such situations is by using a chained conditional.

# %%
#Chained conditions
def comparison(x,y):
    if x < y:
        return 'x is less than y'
    elif x > y:
        return 'x is greater than y'
    else:
        return 'x and y are equal'

# %%
comparison(1,2)

# %% [markdown]
# ## Exercise

# %% [markdown]
# pay = hours * rate

# %%
# Expected interaction:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25

hours = float(input('Enter Hours:\n'))
rate = float(input('Enter Rate:\n'))

print('Pay:', pay)

# %%
# Rewrite your pay computation to give the employee 1.5 times the hourly rate for hours worked above 40 hours.
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

hours = float(input('Enter Hours:\n'))
rate = float(input('Enter Rate:\n'))
